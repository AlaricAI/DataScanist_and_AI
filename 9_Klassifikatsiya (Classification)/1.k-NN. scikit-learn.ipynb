# %%
import pandas as pd
import numpy as np

# %%
url="https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/breast-cancer.csv"
df = pd.read_csv(url)
df.sample(10)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 346    898678         B       12.060         18.90           76.66      445.3
# 505    915276         B        9.676         13.14           64.12      272.5
# 126    866083         M       13.610         24.69           87.76      572.6
# 124    865468         B       13.370         16.39           86.10      553.5
# 366   9011494         M       20.200         26.83          133.70     1234.0
# 557    925236         B        9.423         27.88           59.26      271.3
# 235  88249602         B       14.030         21.25           89.79      603.4
# 97     862261         B        9.787         19.94           62.11      294.5
# 266   8910251         B       10.600         18.95           69.28      346.4
# 184    873885         M       15.280         22.41           98.92      710.6
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 346          0.08386           0.05794        0.007510             0.008488
# 505          0.12550           0.22040        0.118800             0.070380
# 126          0.09258           0.07862        0.052850             0.030850
# 124          0.07115           0.07325        0.080920             0.028000
# 366          0.09905           0.16690        0.164100             0.126500
# 557          0.08123           0.04971        0.000000             0.000000
# 235          0.09070           0.06945        0.014620             0.018960
# 97           0.10240           0.05301        0.006829             0.007937
# 266          0.09688           0.11470        0.063870             0.026420
# 184          0.09057           0.10520        0.053750             0.032630
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 346  ...         13.64          27.06            86.54       562.6
# 505  ...         10.60          18.04            69.47       328.1
# 126  ...         16.89          35.64           113.20       848.7
# 124  ...         14.26          22.75            91.99       632.1
# 366  ...         24.19          33.81           160.00      1671.0
# 557  ...         10.49          34.24            66.50       330.6
# 235  ...         15.33          30.28            98.27       715.5
# 97   ...         10.92          26.29            68.81       366.1
# 266  ...         11.88          22.94            78.28       424.8
# 184  ...         17.80          28.03           113.80       973.1
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 346            0.1289            0.13520          0.04506
# 505            0.2006            0.36630          0.29130
# 126            0.1471            0.28840          0.37960
# 124            0.1025            0.25310          0.33080
# 366            0.1278            0.34160          0.37030
# 557            0.1073            0.07158          0.00000
# 235            0.1287            0.15130          0.06231
# 97             0.1316            0.09473          0.02049
# 266            0.1213            0.25150          0.19160
# 184            0.1301            0.32990          0.36300
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 346               0.05093          0.2880                  0.08083
# 505               0.10750          0.2848                  0.13640
# 126               0.13290          0.3470                  0.07900
# 124               0.08978          0.2048                  0.07628
# 366               0.21520          0.3271                  0.07632
# 557               0.00000          0.2475                  0.06969
# 235               0.07963          0.2226                  0.07617
# 97                0.02381          0.1934                  0.08988
# 266               0.07926          0.2940                  0.07587
# 184               0.12260          0.3175                  0.09772
#
# [10 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df['diagnosis'] = labelencoder.fit_transform(df['diagnosis'].values)
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df.drop(columns=['id'], inplace=True)

# %%
corr_matrix = df.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c031e_row0_col0, #T_c031e_row1_col1, #T_c031e_row1_col3, #T_c031e_row2_col2, #T_c031e_row3_col1, #T_c031e_row3_col3, #T_c031e_row4_col4, #T_c031e_row5_col5, #T_c031e_row6_col6, #T_c031e_row7_col7, #T_c031e_row8_col8, #T_c031e_row9_col9, #T_c031e_row10_col10, #T_c031e_row11_col11, #T_c031e_row12_col12, #T_c031e_row13_col13, #T_c031e_row14_col14, #T_c031e_row15_col15, #T_c031e_row16_col16, #T_c031e_row17_col17, #T_c031e_row18_col18, #T_c031e_row19_col19, #T_c031e_row20_col20, #T_c031e_row21_col21, #T_c031e_row22_col22, #T_c031e_row23_col23, #T_c031e_row24_col24, #T_c031e_row25_col25, #T_c031e_row26_col26, #T_c031e_row27_col27, #T_c031e_row28_col28, #T_c031e_row29_col29, #T_c031e_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col1, #T_c031e_row0_col24, #T_c031e_row1_col0, #T_c031e_row7_col23, #T_c031e_row17_col20 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_c031e_row0_col2, #T_c031e_row0_col25, #T_c031e_row2_col0, #T_c031e_row5_col27, #T_c031e_row9_col27, #T_c031e_row9_col28, #T_c031e_row29_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c031e_row0_col3, #T_c031e_row3_col0, #T_c031e_row3_col14, #T_c031e_row7_col26, #T_c031e_row24_col28, #T_c031e_row28_col24 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c031e_row0_col4, #T_c031e_row4_col0, #T_c031e_row23_col7, #T_c031e_row23_col13 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_c031e_row0_col5, #T_c031e_row10_col19, #T_c031e_row18_col10, #T_c031e_row19_col29, #T_c031e_row24_col22 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_c031e_row0_col6, #T_c031e_row10_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_c031e_row0_col7, #T_c031e_row7_col24, #T_c031e_row13_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_c031e_row0_col8, #T_c031e_row20_col16, #T_c031e_row28_col3 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col9, #T_c031e_row2_col8, #T_c031e_row10_col4, #T_c031e_row10_col18, #T_c031e_row10_col29, #T_c031e_row12_col20, #T_c031e_row13_col5, #T_c031e_row20_col9, #T_c031e_row24_col18 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_c031e_row0_col10, #T_c031e_row8_col12, #T_c031e_row14_col30, #T_c031e_row22_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col11, #T_c031e_row0_col26 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c031e_row0_col12, #T_c031e_row0_col19, #T_c031e_row1_col30, #T_c031e_row2_col5, #T_c031e_row2_col9, #T_c031e_row2_col15, #T_c031e_row2_col19, #T_c031e_row4_col30, #T_c031e_row10_col11, #T_c031e_row10_col13, #T_c031e_row11_col10, #T_c031e_row12_col0, #T_c031e_row12_col6, #T_c031e_row12_col7, #T_c031e_row12_col8, #T_c031e_row14_col29, #T_c031e_row15_col2, #T_c031e_row15_col26, #T_c031e_row19_col0, #T_c031e_row19_col2, #T_c031e_row19_col25, #T_c031e_row19_col27, #T_c031e_row19_col28, #T_c031e_row20_col3, #T_c031e_row20_col21, #T_c031e_row20_col22, #T_c031e_row20_col23, #T_c031e_row20_col24, #T_c031e_row22_col16, #T_c031e_row22_col17, #T_c031e_row22_col18, #T_c031e_row22_col20, #T_c031e_row23_col20, #T_c031e_row30_col1, #T_c031e_row30_col4, #T_c031e_row30_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col13, #T_c031e_row3_col6, #T_c031e_row18_col13, #T_c031e_row28_col13, #T_c031e_row29_col30 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c031e_row0_col14, #T_c031e_row13_col28, #T_c031e_row25_col26, #T_c031e_row28_col25 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_c031e_row0_col15, #T_c031e_row5_col12, #T_c031e_row12_col9, #T_c031e_row12_col24, #T_c031e_row12_col25, #T_c031e_row15_col0, #T_c031e_row15_col14, #T_c031e_row27_col12, #T_c031e_row29_col18 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col16, #T_c031e_row5_col4, #T_c031e_row7_col19, #T_c031e_row16_col21, #T_c031e_row28_col10 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col17, #T_c031e_row17_col24, #T_c031e_row22_col29, #T_c031e_row25_col20 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col18, #T_c031e_row4_col26, #T_c031e_row5_col0, #T_c031e_row20_col26, #T_c031e_row23_col2, #T_c031e_row30_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c031e_row0_col20, #T_c031e_row2_col10, #T_c031e_row3_col19, #T_c031e_row4_col29, #T_c031e_row12_col21, #T_c031e_row18_col29, #T_c031e_row19_col3, #T_c031e_row19_col8, #T_c031e_row19_col22, #T_c031e_row19_col30, #T_c031e_row24_col12, #T_c031e_row24_col30, #T_c031e_row25_col17 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col21, #T_c031e_row10_col30, #T_c031e_row17_col16, #T_c031e_row30_col10 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col22, #T_c031e_row17_col26, #T_c031e_row22_col0, #T_c031e_row25_col29, #T_c031e_row26_col21 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c031e_row0_col23, #T_c031e_row23_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col27, #T_c031e_row7_col13, #T_c031e_row8_col26 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c031e_row0_col28 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_c031e_row0_col29, #T_c031e_row18_col4, #T_c031e_row19_col20 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_c031e_row0_col30, #T_c031e_row5_col18, #T_c031e_row10_col27, #T_c031e_row18_col15, #T_c031e_row22_col26 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c031e_row1_col2, #T_c031e_row1_col18, #T_c031e_row2_col1, #T_c031e_row2_col4, #T_c031e_row4_col2, #T_c031e_row13_col16, #T_c031e_row30_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_c031e_row1_col4, #T_c031e_row3_col4, #T_c031e_row4_col1, #T_c031e_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col5, #T_c031e_row10_col8, #T_c031e_row10_col28 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col6, #T_c031e_row5_col7, #T_c031e_row20_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_c031e_row1_col7, #T_c031e_row6_col5, #T_c031e_row17_col27, #T_c031e_row24_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_c031e_row1_col8, #T_c031e_row4_col8 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col9, #T_c031e_row2_col18, #T_c031e_row18_col22, #T_c031e_row26_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col10, #T_c031e_row25_col15 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_c031e_row1_col11, #T_c031e_row7_col21, #T_c031e_row9_col29, #T_c031e_row11_col1, #T_c031e_row29_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_c031e_row1_col12, #T_c031e_row4_col9, #T_c031e_row8_col19, #T_c031e_row9_col22, #T_c031e_row19_col24 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col13, #T_c031e_row21_col7 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_c031e_row1_col14, #T_c031e_row4_col11, #T_c031e_row11_col4, #T_c031e_row14_col1, #T_c031e_row24_col0 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_c031e_row1_col15, #T_c031e_row9_col23, #T_c031e_row13_col12, #T_c031e_row15_col1, #T_c031e_row15_col23, #T_c031e_row16_col25, #T_c031e_row22_col25, #T_c031e_row22_col30, #T_c031e_row30_col22 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col16, #T_c031e_row10_col14, #T_c031e_row15_col22, #T_c031e_row15_col28, #T_c031e_row20_col0, #T_c031e_row21_col16, #T_c031e_row22_col19, #T_c031e_row25_col2, #T_c031e_row29_col13, #T_c031e_row30_col19 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col17, #T_c031e_row12_col16, #T_c031e_row12_col17, #T_c031e_row14_col12, #T_c031e_row19_col23, #T_c031e_row21_col12, #T_c031e_row24_col19 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col19, #T_c031e_row12_col23, #T_c031e_row15_col30, #T_c031e_row19_col1, #T_c031e_row23_col19, #T_c031e_row24_col17, #T_c031e_row25_col16, #T_c031e_row29_col2, #T_c031e_row29_col15 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c031e_row1_col20, #T_c031e_row12_col30, #T_c031e_row13_col10, #T_c031e_row20_col29 {
#   background-color

# %%
df.corrwith(df['diagnosis']).sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# symmetry_se               -0.006522
# texture_se                -0.008303
# fractal_dimension_mean    -0.012838
# smoothness_se             -0.067016
# dtype: float64

# %%
X = df.drop('diagnosis', axis=1).values
y = df['diagnosis']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Train/test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=12)

# k-NN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5) # k-ni qiymati

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(X_test)

# %%
from sklearn.metrics import jaccard_score

jaccard_score(y_test, y_predict)
# Out:
# np.float64(0.8958333333333334)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(confusion_matrix(y_test, y_predict), annot=True)
plt.show()

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[66,  0],
#        [ 5, 43]])

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
precision = precision_score(y_test, y_predict)
recall = recall_score(y_test, y_predict)
f1 = f1_score(y_test, y_predict)
accuracy = accuracy_score(y_test, y_predict)
print(f"{precision=}\n{recall=}\n{f1=}\n{accuracy=}")
# Out:
# precision=1.0
# recall=0.8958333333333334
# f1=0.945054945054945
# accuracy=0.956140350877193

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        66
#            1       1.00      0.90      0.95        48
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
# Cross validation
from sklearn.model_selection import cross_val_predict
predict = cross_val_predict(estimator = knn, X = X, y = y, cv = 5)

# Modelni baholash
from sklearn.metrics import classification_report
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       357
#            1       0.97      0.93      0.95       212
#
#     accuracy                           0.96       569
#    macro avg       0.97      0.96      0.96       569
# weighted avg       0.96      0.96      0.96       569

# %%
f1 = []
for k in range(1,25):
    knn = KNeighborsClassifier(n_neighbors=k) # k-ni qiymati
    knn.fit(X_train, y_train)
    y_predict = knn.predict(X_test)
    f1.append(f1_score(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(1,25),f1)
plt.xticks(range(1,25))
plt.grid()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_neighbors': np.arange(1, 25)}

knn_gscv = GridSearchCV(knn, param_grid, cv=5)

knn_gscv.fit(X, y)
